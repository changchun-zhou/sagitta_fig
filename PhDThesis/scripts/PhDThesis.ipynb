# %%
# Comparsion with SOTA

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
sys.path.append('../../Nebula/scripts/')
from cls_plt_fig import cls_plt_fig
import pandas as pd
import numpy as np

np.set_printoptions(threshold=np.inf)

pd.set_option('display.width', 300) # 设置字符显示宽度
pd.set_option('display.max_rows', None) # 设置显示最大行
pd.set_option('display.max_columns', None) # 设置显示最大列，None为显示所有列


long_series = pd.Series(np.random.randn(1000))


y1_yticks_max = 12
y2_yticks_max = 12
fig_name ='../generate/SOTA.svg'
work = [    '2010 NEC-UIUC',
            '2011 XRCE',
            '2012 AlexNet', 
            '2013 Clarifia',
             '2014 VGG-16',  
             '2015 ResNet', 
             '2016 GoogLeNet-v4', 
             '2017 SENet',
             '2018 ResNeXt-101',
             '2019 FixResNeXt-101',
             '2020 EfficientNet-L2',
             '2021 EfficientNet-L2',
             '2022 Florence-CoSwin-H']
work = [     '2010',
             '2011',
             '2012', 
             '2013',
             '2014',  
             '2015',
             '2016',
             '2017',
             '2018',
             '2019',
             '2020',
             '2021',
             '2022']
frame_energy                    = np.array([28, 26, 16.3, 13, 7.5, 3.5, 3, 2.25, 2.2, 2, 1.2, 1.2, 1])

x_value = np.arange(len(work))
# x_label = "${Works}$"

xticks = work
legend_loc = (0.01, 0.75)
len_yticks = [6, 11]
figsize=(7,3)

bar_width = 0.2
y1_yticks_max = 700
y2_yticks_max = 110

y_value = np.array([[frame_energy]])
y_label = ['Top-5 Error']
y_fig_type = [['bar', 'bar', 'bar'], ['bar']]
# y_legend = [['Energy Efficiency Improvement', 'Energy Consumption Reduction', 'Overall Efficiency Improvement']]
# legend_ncol = 1
y_color=[[(49/255, 101/255, 162/255), (1, 1, 1), (220/255, 103/255, 103/255) ]]
y_yticks_max = [30]

cls_plt_fig('').func_plt_fig(
    fig_name=fig_name,
    x_value=x_value,
    y_label = y_label,
    y_value = y_value,
    y_fig_type = y_fig_type,
    # y_legend = y_legend,
    y_color = y_color,
    y_axis_color = [(0, 0, 0)],
    y_edgecolor = [[(49/255, 101/255, 162/255), (49/255, 101/255, 162/255), (220/255, 103/255, 103/255)],[]],
    y_yticks_max=y_yticks_max,
    y_yticks_min=[0, 0],
    len_yticks=len_yticks,
    xticks= xticks,
    # legend_loc =legend_loc,
    figsize=figsize, #[0, 0, 1, 1],
    font_size = 10,
    plt_text = True,
    # legend_ncol=legend_ncol,
    labelrotation = 0,
    bar_width = bar_width,
    bar_gap_width = 0.08,
    border_width = 0.5
)

# %%
# Comparsion with SOTA

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
sys.path.append('../../Nebula/scripts/')
from cls_plt_fig import cls_plt_fig
import pandas as pd
import numpy as np

np.set_printoptions(threshold=np.inf)

pd.set_option('display.width', 300) # 设置字符显示宽度
pd.set_option('display.max_rows', None) # 设置显示最大行
pd.set_option('display.max_columns', None) # 设置显示最大列，None为显示所有列


long_series = pd.Series(np.random.randn(1000))


y1_yticks_max = 12
y2_yticks_max = 12
fig_name ='../generate/Computation_Operations.svg'
work = [     2012.3,      
             2014.6,      
             2015.9,      
             2015.9,      
             2016.8,      
             2016.9,      
             2016.9,     
             2017.9,      
             2018.1,      
             2018.4,      
             2018.7,      
             2019.5,      
             2020.1,
             2020.4       ]

frame_energy                    = np.array([
450     ,
10000   ,
10000   ,
100000  ,
500000  ,
11000   ,
3000    ,
30000   ,
4000    ,
70000   ,
700000  ,
6000000 ,
40000000,
4e+8
]

)

x_value = np.array(work)
x_label = "Year"

xticks = work
legend_loc = (0.01, 0.75)
len_yticks = [6, 11]
figsize=(10,3)

bar_width = 0.2
y1_yticks_max = 700
y2_yticks_max = 110

y_value = np.array([[frame_energy]])

y_label = ['Computation (FLOPS)']
# y_label = ['Normalization Scaling']
y_fig_type = [['plot', 'bar', 'bar'], ['bar']]
plt_content = [[[
'AlexNet',
'VGG',
'ResNet',
'InceptionV3',
'Xception',
'ResNeXt',
'DenseNet',
'Transformer',
'ELMo',
'GPT-1',
'BERT',
'XLNet',
'Microsoft T-NLG',
'GPT-3' 
]]]
# legend_ncol = 1
y_color=[[(1, 1, 1), (1, 1, 1), (220/255, 103/255, 103/255) ]]
y_yticks_max = [50000000]

cls_plt_fig('').func_plt_fig(
    fig_name=fig_name,
    x_label = x_label,
    x_value=x_value,
    y_label = y_label,
    y_value = y_value,
    y_fig_type = y_fig_type,
    # y_legend = y_legend,
    y_color = y_color,
    y_axis_color = [(0, 0, 0)],
    y_markerfacecolor=[[(0, 0, 0), (49/255, 101/255, 162/255), (220/255, 103/255, 103/255)],[]],
    y_edgecolor = [[(0, 0, 0), (49/255, 101/255, 162/255), (220/255, 103/255, 103/255)],[]],
    y_linestyle = [[None]],
    linewidth = 0,
    y_marker = [['o', 'v', 's', '*',  '<', '.', 'v', 's', '*', 'o', '<', '.']],
    y_markersize = [[9]],
    y_yticks_max=y_yticks_max,
    y_yticks_min=[0, 0],
    len_yticks=len_yticks,
    xticks= xticks,
    # legend_loc =legend_loc,
    figsize=figsize, #[0, 0, 1, 1],
    font_size = 12,
    plt_content=plt_content,
    plt_text = True,
    # legend_ncol=legend_ncol,
    labelrotation = 0,
    bar_width = bar_width,
    bar_gap_width = 0.08,
    border_width = 1,
    minor = True
)
