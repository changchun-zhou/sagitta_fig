# %%
# Comparsion with SOTA

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
sys.path.append('../../Nebula/scripts/')
from cls_plt_fig import cls_plt_fig
import pandas as pd
import numpy as np

np.set_printoptions(threshold=np.inf)

pd.set_option('display.width', 300) # 设置字符显示宽度
pd.set_option('display.max_rows', None) # 设置显示最大行
pd.set_option('display.max_columns', None) # 设置显示最大列，None为显示所有列


long_series = pd.Series(np.random.randn(1000))


y1_yticks_max = 12
y2_yticks_max = 12
fig_name ='../generate/SOTA.svg'
work = [    '2010 NEC-UIUC',
            '2011 XRCE',
            '2012 AlexNet', 
            '2013 Clarifia',
             '2014 VGG-16',  
             '2015 ResNet', 
             '2016 GoogLeNet-v4', 
             '2017 SENet',
             '2018 ResNeXt-101',
             '2019 FixResNeXt-101',
             '2020 EfficientNet-L2',
             '2021 EfficientNet-L2',
             '2022 Florence-CoSwin-H']
work = [     '2010',
             '2011',
             '2012', 
             '2013',
             '2014',  
             '2015',
             '2016',
             '2017',
             '2018',
             '2019',
             '2020',
             '2021',
             '2022']
frame_energy                    = np.array([28, 26, 16.3, 13, 7.5, 3.5, 3, 2.25, 2.2, 2, 1.2, 1.2, 1])

x_value = np.arange(len(work))
# x_label = "${Works}$"

xticks = work
legend_loc = (0.01, 0.75)
len_yticks = [6, 11]
figsize=(7,3)

bar_width = 0.2
y1_yticks_max = 700
y2_yticks_max = 110

y_value = np.array([[frame_energy]])
y_label = ['Top-5 Error']
y_fig_type = [['bar', 'bar', 'bar'], ['bar']]
# y_legend = [['Energy Efficiency Improvement', 'Energy Consumption Reduction', 'Overall Efficiency Improvement']]
# legend_ncol = 1
y_color=[[(49/255, 101/255, 162/255), (1, 1, 1), (220/255, 103/255, 103/255) ]]
y_yticks_max = [30]

cls_plt_fig('').func_plt_fig(
    fig_name=fig_name,
    x_value=x_value,
    y_label = y_label,
    y_value = y_value,
    y_fig_type = y_fig_type,
    # y_legend = y_legend,
    y_color = y_color,
    y_axis_color = [(0, 0, 0)],
    y_edgecolor = [[(49/255, 101/255, 162/255), (49/255, 101/255, 162/255), (220/255, 103/255, 103/255)],[]],
    y_yticks_max=y_yticks_max,
    y_yticks_min=[0, 0],
    len_yticks=len_yticks,
    xticks= xticks,
    # legend_loc =legend_loc,
    figsize=figsize, #[0, 0, 1, 1],
    font_size = 10,
    plt_text = True,
    # legend_ncol=legend_ncol,
    labelrotation = 0,
    bar_width = bar_width,
    bar_gap_width = 0.08,
    border_width = 0.5
)

# %%
# Comparsion with SOTA

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
sys.path.append('../../Nebula/scripts/')
from cls_plt_fig import cls_plt_fig
import pandas as pd
import numpy as np

np.set_printoptions(threshold=np.inf)

pd.set_option('display.width', 300) # 设置字符显示宽度
pd.set_option('display.max_rows', None) # 设置显示最大行
pd.set_option('display.max_columns', None) # 设置显示最大列，None为显示所有列


long_series = pd.Series(np.random.randn(1000))


y1_yticks_max = 12
y2_yticks_max = 12
fig_name ='../generate/Computation_Operations.svg'
work = [     2012.3,      
             2014.6,      
             2015.9,      
             2015.9,      
             2016.8,      
             2016.9,      
             2016.9,     
             2017.9,      
             2018.1,      
             2018.4,      
             2018.7,      
             2019.5,      
             2020.1,
             2020.4       ]

frame_energy                    = np.array([
450     ,
10000   ,
10000   ,
100000  ,
500000  ,
11000   ,
3000    ,
30000   ,
4000    ,
70000   ,
700000  ,
6000000 ,
40000000,
4e+8
]

)

x_value = np.array(work)
x_label = "Year"

xticks = work
legend_loc = (0.01, 0.75)
len_yticks = [6, 11]
figsize=(10,3)

bar_width = 0.2
y1_yticks_max = 700
y2_yticks_max = 110

y_value = np.array([[frame_energy]])

y_label = ['Computation (FLOPS)']
# y_label = ['Normalization Scaling']
y_fig_type = [['plot', 'bar', 'bar'], ['bar']]
plt_content = [[[
'AlexNet',
'VGG',
'ResNet',
'InceptionV3',
'Xception',
'ResNeXt',
'DenseNet',
'Transformer',
'ELMo',
'GPT-1',
'BERT',
'XLNet',
'Microsoft T-NLG',
'GPT-3' 
]]]
# legend_ncol = 1
y_color=[[(1, 1, 1), (1, 1, 1), (220/255, 103/255, 103/255) ]]
y_yticks_max = [50000000]

cls_plt_fig('').func_plt_fig(
    fig_name=fig_name,
    x_label = x_label,
    x_value=x_value,
    y_label = y_label,
    y_value = y_value,
    y_fig_type = y_fig_type,
    # y_legend = y_legend,
    y_color = y_color,
    y_axis_color = [(0, 0, 0)],
    y_markerfacecolor=[[(0, 0, 0), (49/255, 101/255, 162/255), (220/255, 103/255, 103/255)],[]],
    y_edgecolor = [[(0, 0, 0), (49/255, 101/255, 162/255), (220/255, 103/255, 103/255)],[]],
    y_linestyle = [[None]],
    linewidth = 0,
    y_marker = [['o', 'v', 's', '*',  '<', '.', 'v', 's', '*', 'o', '<', '.']],
    y_markersize = [[9]],
    y_yticks_max=y_yticks_max,
    y_yticks_min=[0, 0],
    len_yticks=len_yticks,
    xticks= xticks,
    # legend_loc =legend_loc,
    figsize=figsize, #[0, 0, 1, 1],
    font_size = 12,
    plt_content=plt_content,
    plt_text = True,
    # legend_ncol=legend_ncol,
    labelrotation = 0,
    bar_width = bar_width,
    bar_gap_width = 0.08,
    border_width = 1,
    minor = True
)

# %%
# BW Bottleneck

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
sys.path.append('../../Nebula/scripts/')
from cls_plt_fig import cls_plt_fig
import pandas as pd
import numpy as np

np.set_printoptions(threshold=np.inf)

pd.set_option('display.width', 300) # 设置字符显示宽度
pd.set_option('display.max_rows', None) # 设置显示最大行
pd.set_option('display.max_columns', None) # 设置显示最大列，None为显示所有列

long_series = pd.Series(np.random.randn(1000))

y1_yticks_max = 12
y2_yticks_max = 12


work = [     2012.3,      
             2014.6,      
             2015.9,      
             2015.9,      
             2016.8,      
             2016.9,      
             2016.9,     
             2017.9,      
             2018.1,      
             2018.4,      
             2018.7,      
             2019.5,      
             2020.1,
             2020.4       ]

fig_name ='../generate/BW_BottleNeck.svg'
work = [[     1997.1, 
             1998.1,
             2002.5,
             2008.1, 
             2010.12, 
             2014.1, 
             2016.1, 
             2018.3, 
             2020.4, # A100  
             2022, # TPUv4
             2023 # H100
      ],
      [     2003.8, 
             2006.98,
             2008.5,
             2012.1, 
             2015.6, 
             2017.5, 
             2020.6, 
             2022.3, 
      ],
      [     2003.1, 
             2007.1,
             2010.98,
             2014.1, 
             2016.3, 
             2019.4, 
             2022.1
      ]
]


frame_energy                    = np.array([
[
1,
0.85,
60,
1500,
6000,
20000,
150000,
500000,
1000000,
900000,
2000000
],
[
3,
11,
18,
23,
50,
80,
100,
500
],
[
1,
4,
10,
13,
20,
26,
40
]]

)

plt_content = [[
[
'R10000',
' ',
'Itanium 2',
' ',
'GTX 580',
'K40',
'KNL',
'TPUv3',
'A100',
'TPUv4',
'H100'
],
[
'GDDR3',
'GDDR4',
'GDDR5',
' ',
'HBM',
'HBM2',
' ',
'HBM2E'
],
[
'PCle 1.0a',
'PCle 2.0',
'PCle 3.0',
' ',
'NVLink 1.0',
'PCle 5.0',
'NVLink 4.0'
]
]]

x_value = np.array(work)
x_label = "Year"

xticks = work
legend_loc = (0.01, 0.75)
len_yticks = [6, 11]
figsize=(10,5)

bar_width = 0.2
y1_yticks_max = 700
y2_yticks_max = 110

y_value = np.array([frame_energy])

y_label = ['Normalization Scaling']
y_fig_type = [['plot', 'plot', 'plot'], ['bar']]

# legend_ncol = 1
y_color=[[(1, 1, 1), (1, 1, 1), (220/255, 103/255, 103/255) ]]
y_yticks_max = [50000000]

cls_plt_fig('').func_plt_fig(
    fig_name=fig_name,
    x_label = x_label,
    x_value=x_value,
    y_label = y_label,
    y_value = y_value,
    y_fig_type = y_fig_type,
    # y_legend = y_legend,
    y_color = y_color,
    y_axis_color = [(0, 0, 0)],
    y_markerfacecolor=[[(0, 0, 0),(49/255, 101/255, 162/255), (214/255, 73/255, 73/255)],[]],
    y_edgecolor = [[(0, 0, 0), (49/255, 101/255, 162/255), (214/255, 73/255, 73/255)],[]],
    # y_linestyle = [[None]],
    linewidth = 0,
    y_marker = [['o', 'v', 's', '*',  '<', '.', 'v', 's', '*', 'o', '<', '.']],
    y_markersize = [[9,11,9]],
    y_yticks_max=y_yticks_max,
    y_yticks_min=[0, 0],
    len_yticks=len_yticks,
    xticks= xticks,
    # legend_loc =legend_loc,
    figsize=figsize, #[0, 0, 1, 1],
    font_size = 12,
    plt_content=plt_content,
    plt_text = True,
    # legend_ncol=legend_ncol,
    labelrotation = 0,
    bar_width = bar_width,
    bar_gap_width = 0.08,
    border_width = 1,
    minor = True
)

# %%
# Memory BottleNeck

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
sys.path.append('../../Nebula/scripts/')
from cls_plt_fig import cls_plt_fig
import pandas as pd
import numpy as np

np.set_printoptions(threshold=np.inf)

pd.set_option('display.width', 300) # 设置字符显示宽度
pd.set_option('display.max_rows', None) # 设置显示最大行
pd.set_option('display.max_columns', None) # 设置显示最大列，None为显示所有列

long_series = pd.Series(np.random.randn(1000))

y1_yticks_max = 12
y2_yticks_max = 12

fig_name ='../generate/MEM_BottleNeck.svg'
work = [[    2016.5, 
             2017.3,
             2017.5,
             2018.4, 
             2019.3, 
             2020.4,
             2020.85, 
             2022.3, 
      ],
      [      2016,  #resnet50
             2016.2,
             2016.90,  #resnext101
             2016.95,  #densenet
             2017.95,  #transformer
             2018.5,   #GPT-1 
             2018.9,   
             2019.2, 
             2019.7,
             2020.2,
             2020.5,
             2020.6,
             2021.1,
             2021.8

      ]
]


frame_energy                    = np.array([
    [
1.2,
2,
5,
6,
6,
5,
15,
15
],
[
0.025,
0.09,
0.08,
0.028,
0.04,
0.13,
0.23,
1.5,
7,
16,
200,
450,
1700,
400
]
]
)

plt_content = [[
[
'P100 (12GB)',
'TPUv2 (16GB)',
'V100 (32GB)',
'TPUv3 (32GB)',
' ',
'A100 (40GB)',
'A100(80GB)',
'H100 (80GB)'
],
[
'ResNet50',
'Inception',
'ResNext101',
'DenseNet',
'Transformer',
'GPT-1',
'BERT',
'GPT-2',
'Megatron LM',
'T-NLG',
'GPT3',
'GShard',
'Switch Transformer',
'Megatron-Turing'
]
]]

x_value = np.array(work)
x_label = "Year"

xticks = work
legend_loc = (0.01, 0.75)
len_yticks = [6, 11]
figsize=(10,5)

bar_width = 0.2
y1_yticks_max = 700
y2_yticks_max = 110

y_value = np.array([frame_energy])

y_label = ['Parameters (Billion)']
y_fig_type = [['plot', 'plot', 'plot'], ['bar']]

# legend_ncol = 1
y_color=[[(1, 1, 1), (1, 1, 1), (220/255, 103/255, 103/255) ]]
y_yticks_max = [50000000]

cls_plt_fig('').func_plt_fig(
    fig_name=fig_name,
    x_label = x_label,
    x_value=x_value,
    y_label = y_label,
    y_value = y_value,
    y_fig_type = y_fig_type,
    # y_legend = y_legend,
    y_color = y_color,
    y_axis_color = [(0, 0, 0)],
    y_markerfacecolor=[[(0, 0, 0),(49/255, 101/255, 162/255), (214/255, 73/255, 73/255)],[]],
    y_edgecolor = [[(0, 0, 0), (49/255, 101/255, 162/255), (214/255, 73/255, 73/255)],[]],
    # y_linestyle = [[None]],
    linewidth = 0,
    y_marker = [['o', 'v', 's', '*',  '<', '.', 'v', 's', '*', 'o', '<', '.']],
    y_markersize = [[9,11,9]],
    y_yticks_max=y_yticks_max,
    y_yticks_min=[0, 0],
    len_yticks=len_yticks,
    xticks= xticks,
    # legend_loc =legend_loc,
    figsize=figsize, #[0, 0, 1, 1],
    font_size = 12,
    plt_content=plt_content,
    plt_text = True,
    # legend_ncol=legend_ncol,
    labelrotation = 0,
    bar_width = bar_width,
    bar_gap_width = 0.08,
    border_width = 1,
    minor = True
)

# %%
# Stage Enhance
# Technique Effect

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
sys.path.append('../../Nebula/scripts/')
from cls_plt_fig import cls_plt_fig

fig_name ='../generate/PointNeXtvsOther.svg'
Stages = ['PointNet++','DGCNN','PointCNN', 'PointMLP', 'PointNeXt']
Speedup = [[
0.779,
0.781,
0.785,
0.854,
0.877
]]
NEE = [[
    0.545, 
    0.561, 
    0.654, 
    0.40, 
    0.749]]

x_value = np.arange(len(Stages))

figsize=(7,3)

bar_width = 0.15
xticks = Stages
legend_loc = (0.13, 0.93)

y_value = [Speedup, NEE]
y_label = ['Overall Accuray on ScanObjectNN', 'mIoU on S3DIS']
y_fig_type = [['bar'], ['bar']]
y_legend = [['Overall Accuray on ScanObjectNN'], ['mIoU on S3DIS']]
legend_ncol = 2
y_color=[[(49/255, 101/255, 162/255), (97/255, 169/255, 218/255)], [(220/255, 103/255, 103/255),(1,1,1)]]
len_yticks = [5, 5]
y_yticks_max = [0.9, 0.75]

print(y_value)

cls_plt_fig('').func_plt_fig(
    fig_name=fig_name,
    x_value=x_value,
    y_label = y_label,
    y_value = y_value,
    y_fig_type = y_fig_type,
    y_legend = y_legend,
    y_color = y_color,
    y_axis_color = [(0/255, 77/255, 144/255), (214/255, 73/255, 73/255)],
    y_yticks_max=y_yticks_max,
    y_yticks_min=[0.75, 0.5],
    y_edgecolor = [[(49/255, 101/255, 162/255), (97/255, 169/255, 218/255)],[(220/255, 103/255, 103/255)]],
    y_facecolor = [[(49/255, 101/255, 162/255), (97/255, 169/255, 218/255)],[(220/255, 103/255, 103/255)]],
    y_hatch = [[None, None],[None, None]],
    y_linestyle=[['-' for i in range(np.shape(y_value)[1])] for j in range(np.shape(y_value)[0])],
    y_marker = [[],['s','*']],
    len_yticks=len_yticks,
    xticks= xticks,
    legend_loc =legend_loc,
    legend_columnspacing = 3,
    figsize=figsize,
    font_size = 10,
    plt_text = False,
    plt_text_first = False,
    plt_text_format = '%d',
    legend_ncol=legend_ncol,
    labelrotation = 0,
    bar_width = bar_width,
    linewidth= 2,
    bar_gap_width = 0.07,
    border_width = 0.4,
    ylim_min = 0.5,
    PercentFormatter=[True, True]
)
# Out:
# [[[0.779, 0.781, 0.785, 0.854, 0.877]], [[0.545, 0.561, 0.654, 0.4, 0.749]]]
# [-0.11  0.89  1.89  2.89  3.89]
# [[[0.779, 0.781, 0.785, 0.854, 0.877]], [[0.545, 0.561, 0.654, 0.4, 0.749]]]
# [0.11 1.11 2.11 3.11 4.11]
# [[[0.779, 0.781, 0.785, 0.854, 0.877]], [[0.545, 0.561, 0.654, 0.4, 0.749]]]

# %%
# Area & Energy Breakdown

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# case = 'Area'
case = 'Energy'

if case == 'Area':
    # top-level
    fig_name = '../generate/Area_Breakdown.svg'
    startangle = 40
    area = np.array([313175.00, 246282.00, 302643.00, 46104.00, 268604.00, 61047.00])
elif case == 'Energy':
    # intra-PE
    fig_name = '../generate/Energy_Breakdown.svg'
    startangle= 0
    # 5 Tech.
    area = np.array([125205000.00, 73229535.27, 2082880491.83, 15534690.94, 840115300.56, 56057260.34])
    # # 3 Tech.
    # area = np.array([48.8, 1.74, 9463.9, 16.78, 2290.3, 17.1])

fontsize = 18
radius = 1.2
loc_legend = (-0.07,-0.25)
legend = ['Sampling', 'Grouping', 'Convolution', 'Pooling', 'Memory','Other'] #(Control, Interface, etc.)
# Convolution:  (113/255, 155/255, 203/255), blue
# Sampling:     (255/255, 100/255, 100/255), red
# 'Grouping':   (255/255, 180/255, 123/255), yellow
# Pooling:      (0/255,173/255,186/255), royal / (0, 128/256, 0) green
# Memory:       
# Other:        (191/255, 191/255, 191/255), gray
colors = [(255/255, 180/255, 123/255), 
          (180/255,102/255, 182/255),
          (255/255, 100/255, 100/255),
          (191/255, 191/255, 191/255),
          (113/255, 155/255, 203/255),
          (0/255,173/255,186/255)]

labels = ['{:.1f}% '.format(area[0]/sum(area)*100), 
          '{:.1f}%'.format(area[1]/sum(area)*100), 
          '{:.1f}%'.format(area[2]/sum(area)*100), 
          '{:.1f}%'.format(area[3]/sum(area)*100), 
          '{:.1f}%'.format(area[4]/sum(area)*100),
           '{:.1f}%'.format(area[5]/sum(area)*100) 
]
plt.subplots(figsize=(5, 5))
# 绘制圆环图，并返回饼块对象
wedges, texts = plt.pie(area, colors=colors, startangle=startangle, radius=radius, wedgeprops={'linewidth': 0.1, 'edgecolor': "white"})

kw = dict(zorder=10, va="center", ha="center")

for i, p in enumerate(wedges):
    # 根据matplotlib.patches.Wedge对象的theta1和theta2参数计算饼块均分点的角度
    ang = (p.theta2 - p.theta1) / 2.0 + p.theta1
    # 根据角度的弧度计算 饼块均分点的坐标（引导线的起点）
    y = np.sin(np.deg2rad(ang))
    x = np.cos(np.deg2rad(ang))
    print(p.theta1, p.theta2, ang, np.deg2rad(ang), x, y)
    horizontalalignment = {-1: "right", 1: "left"}[int(np.sign(x))]
    # 设置引导线的连接方式
    connectionstyle = "angle,angleA=0,angleB={}".format(ang)
    plt.annotate(
        labels[i],
        xy=(radius*x*0.8, radius*y*0.8),
        xytext=(radius*x*0.8, radius*y*0.8),#(radius* np.sign(x)*1.2, y),
        # horizontalalignment=horizontalalignment,
        **kw,
        
        fontsize=fontsize
        # **kw
    )

# plt.legend(wedges, legend, loc=loc_legend, ncol=2, fontsize=fontsize, frameon=False, handletextpad=0.1,columnspacing=5 )
plt.savefig(fig_name, format='svg')
plt.show()
# Out:
# 0.0 14.116342663764954 7.058171331882477 0.12318832891122264 0.9924219084443476 0.12287699393978833
# 14.116342663764954 22.37266816198826 18.244505412876606 0.31842668985262423 0.9497291538168471 0.3130727301927392
# 22.37266816198826 257.20877923071384 139.79072369635105 2.439808392246984 -0.7636915177076056 0.6455813393999659
# 257.20877923071384 258.96025098860264 258.08451510965824 4.5044245370765905 -0.20646863197186785 -0.9784532201447678
# 258.96025098860264 353.679758682847 306.32000483572483 5.34629264910835 0.5922945327695563 -0.8057215315797964
# 353.679758682847 359.9999812245369 356.83986995369196 6.22803063308031 0.9984793665065569 -0.05512671458254001

# %%
# Technique Effect

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
sys.path.append('../../Nebula/scripts/')
from cls_plt_fig import cls_plt_fig

fig_name ='../generate/Technique.svg'
Techniques = ['Baseline','EFP','EFP+ABF','EFP+ABF+BMF', 'EFP+ABF'+'\n'+'+BMF+BPDA', 'EFP+ABF+BMF'+'\n'+'+BPDA+SBS'] # 18
Speedup = [[1, 1.53, 8, 14.41, 72.56, 78.56]]
NEE = np.array([[0.68, 3.66, 8.06, 8.87, 42.27, 46.03]])/0.68

x_value = np.arange(len(Techniques))

figsize=(7,3)

bar_width = 0.15
xticks = Techniques
legend_loc = (0.18, 0.93)

y_value = [Speedup, NEE]
y_label = ['Speedup', 'Normalized Energy Efficiency']
y_fig_type = [['bar'], ['bar']]
y_legend = [['Speedup'], ['Normalized Energy Efficiency']]
legend_ncol = 2
y_color=[[(49/255, 101/255, 162/255),(1,1,1)], [(220/255, 103/255, 103/255), (226/255, 129/255, 128/255)]]
len_yticks = [8, 8]
y_yticks_max = [80, 80]

print(y_value)
print('Seperate Tech. Speedup:')
for i in range(len(Techniques)-1):
    print(Speedup[0][i+1]/Speedup[0][i])
print('Seperate Tech. EE Improvement:')
for i in range(len(Techniques)-1):    
    print(NEE[0][i+1]/NEE[0][i])

cls_plt_fig('').func_plt_fig(
    fig_name=fig_name,
    x_value=x_value,
    y_label = y_label,
    y_value = y_value,
    y_fig_type = y_fig_type,
    y_legend = y_legend,
    y_color = y_color,
    y_axis_color = [(0/255, 77/255, 144/255), (214/255, 73/255, 73/255)],
    y_yticks_max=y_yticks_max,
    y_yticks_min=[0, 0],
    y_edgecolor = [[(49/255, 101/255, 162/255), (97/255, 169/255, 218/255)],[(220/255, 103/255, 103/255)]],
    y_linestyle=[['-' for i in range(np.shape(y_value)[1])] for j in range(np.shape(y_value)[0])],
    y_marker = [[],['s','*']],
    len_yticks=len_yticks,
    xticks= xticks,
    legend_loc =legend_loc,
    figsize=figsize, #[0, 0, 1, 1],
    font_size = 10,
    plt_text = True,
    plt_text_first = True,
    plt_text_format = '%d',
    legend_ncol=legend_ncol,
    legend_columnspacing = 1,
    labelrotation = 0,
    bar_width = bar_width,
    linewidth= 2,
    bar_gap_width = 0.1
)
# Out:
# [[[1, 1.53, 8, 14.41, 72.56, 78.56]], array([[ 1.        ,  5.38235294, 11.85294118, 13.04411765, 62.16176471,
#         67.69117647]])]
# Seperate Tech. Speedup:
# 1.53
# 5.228758169934641
# 1.80125
# 5.035392088827203
# 1.0826901874310915
# Seperate Tech. EE Improvement:
# 5.38235294117647
# 2.2021857923497272
# 1.1004962779156324
# 4.765501691093575
# 1.088951975396262

# %%
# Stage Enhance
# Technique Effect

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
sys.path.append('../../Nebula/scripts/')
from cls_plt_fig import cls_plt_fig

fig_name ='../generate/Enhance_Stage.svg'
Stages = ['Stage1','Stage2','Stage3', 'Stage4', 'Stage5']
Speedup = np.array([[
9.192,
8.38,
18.17,
22.8,
30.07
]])*78.56/15.32
NEE = np.array([[5.899, 8.37, 18.13, 22.62, 28.13]])*68.07/13.6

x_value = np.arange(len(Stages))

figsize=(7,3)

bar_width = 0.15
xticks = Stages
legend_loc = (0.15, 0.93)

y_value = [Speedup, NEE]
y_label = ['Speedup', 'Energy Efficiency Improvement']
y_fig_type = [['bar'], ['bar']]
y_legend = [['Speedup'], ['Energy Efficiency Improvement']]
legend_ncol = 2
y_color=[[(49/255, 101/255, 162/255),(1,1,1)], [(220/255, 103/255, 103/255),(1,1,1)]]
len_yticks = [8, 8]
y_yticks_max = [160, 160]

print(y_value)

cls_plt_fig('').func_plt_fig(
    fig_name=fig_name,
    x_value=x_value,
    y_label = y_label,
    y_value = y_value,
    y_fig_type = y_fig_type,
    y_legend = y_legend,
    y_color = y_color,
    y_axis_color = [(0/255, 77/255, 144/255), (214/255, 73/255, 73/255)],
    y_yticks_max=y_yticks_max,
    y_yticks_min=[0, 0],
    y_edgecolor = [[(49/255, 101/255, 162/255), (97/255, 169/255, 218/255)],[(220/255, 103/255, 103/255)]],
    y_hatch = [[None, None],[None, None]],
    y_linestyle=[['-' for i in range(np.shape(y_value)[1])] for j in range(np.shape(y_value)[0])],
    y_marker = [[],['s','*']],
    len_yticks=len_yticks,
    xticks= xticks,
    legend_loc =legend_loc,
    legend_columnspacing = 3,
    figsize=figsize,
    font_size = 10,
    plt_text = False,
    plt_text_first = False,
    plt_text_format = '%d',
    legend_ncol=legend_ncol,
    labelrotation = 0,
    bar_width = bar_width,
    linewidth= 2,
    bar_gap_width = 0.1,
    border_width = 0.5
)
# Out:
# [array([[ 47.136     ,  42.97211488,  93.17462141, 116.91697128,
#         154.19707572]]), array([[ 29.5253625 ,  41.89308088,  90.74331618, 113.21642647,
#         140.79478676]])]

# %%
# Comparsion with SOTA

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
sys.path.append('../../Nebula/scripts/')
from cls_plt_fig import cls_plt_fig

import pandas as pd
import numpy as np
np.set_printoptions(threshold=np.inf)

pd.set_option('display.width', 300) # 设置字符显示宽度
pd.set_option('display.max_rows', None) # 设置显示最大行
pd.set_option('display.max_columns', None) # 设置显示最大列，None为显示所有列


long_series = pd.Series(np.random.randn(1000))


y1_yticks_max = 12
y2_yticks_max = 12
fig_name ='../generate/SOTA.svg'
work = [    'Mesorasi',
            'PointAcc',
            'Point-X', 
            'Crescent',
             'PNNPU',  
             '[14]', 
             '[15]', 
             'This Work']
frame_energy                    = np.array([8.92, 1.54, 0.25, 0.46248, 1.47, 5.77, 1.9, 0.0348])
frame_energy_reduction          = frame_energy[0]/frame_energy # /np.max(frame_energy)
energy_efficiency               = np.array([0.19, 1.1, 0.8586, 3.6758, 5.65, 1.5, 4.14, 46.03])
energy_efficiency_Improvement   = energy_efficiency / energy_efficiency[0]

Overall = np.array([0.072, 0.167, 0.59, 1.395, 0.0425, 0.04227, 0.2, 1/frame_energy[-1]/1.5077])
print("Nebula overall efficiency", Overall[-1])
Overall_Improvement = Overall/Overall[0]
x_value = np.arange(len(work))
# x_label = "${Works}$"

xticks = work
legend_loc = (0.01, 0.75)
len_yticks = [9, 11]
figsize=(7,3)

bar_width = 0.2
y1_yticks_max = 700
y2_yticks_max = 110

y_value = np.array([[energy_efficiency_Improvement, frame_energy_reduction, Overall_Improvement]])
y_label = ['Improvement']
y_fig_type = [['bar', 'bar', 'bar'], ['bar']]
y_legend = [['Energy Efficiency Improvement', 'Energy Consumption Reduction', 'Overall Efficiency Improvement']]
legend_ncol = 1
y_color=[[(49/255, 101/255, 162/255), (1, 1, 1), (220/255, 103/255, 103/255) ]]
y_yticks_max = [270]

print(y_value)
for j in range(3):
    for i in range(len(work)):
        print(y_value[0][j][-1]/y_value[0][j][i])

cls_plt_fig('').func_plt_fig(
    fig_name=fig_name,
    x_value=x_value,
    y_label = y_label,
    y_value = y_value,
    y_fig_type = y_fig_type,
    y_legend = y_legend,
    y_color = y_color,
    y_axis_color = [(0, 0, 0)],
    y_edgecolor = [[(49/255, 101/255, 162/255), (49/255, 101/255, 162/255), (220/255, 103/255, 103/255)],[]],
    y_yticks_max=y_yticks_max,
    y_yticks_min=[0, 0],
    len_yticks=len_yticks,
    xticks= xticks,
    legend_loc =legend_loc,
    figsize=figsize, #[0, 0, 1, 1],
    font_size = 10,
    plt_text = True,
    legend_ncol=legend_ncol,
    labelrotation = 0,
    bar_width = bar_width,
    bar_gap_width = 0.08,
    border_width = 0.5
)
# Out:
# Nebula overall efficiency 19.059250636007196
# [[[  1.           5.78947368   4.51894737  19.34631579  29.73684211
#      7.89473684  21.78947368 242.26315789]
#   [  1.           5.79220779  35.68        19.28732053   6.06802721
#      1.54592721   4.69473684 256.32183908]
#   [  1.           2.31944444   8.19444444  19.375        0.59027778
#      0.58708333   2.77777778 264.71181439]]]
# 242.26315789473685
# 41.845454545454544
# 53.61052876776147
# 12.52244409380271
# 8.146902654867256
# 30.686666666666667
# 11.118357487922706
# 1.0
# 256.32183908045977
# 44.252873563218394
# 7.183908045977011
# 13.289655172413793
# 42.24137931034483
# 165.80459770114942
# 54.59770114942528
# 1.0
# 264.71181438898884
# 114.12724931740836
# 32.303814637300334
# 13.66254525878652
# 448.4529561413457
# 450.8930834163046
# 95.29625318003598
# 1.0

# %%
# Comparsion with SOTA-Sagitta

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
sys.path.append('../../Nebula/scripts/')
from cls_plt_fig import cls_plt_fig

import pandas as pd
import numpy as np
np.set_printoptions(threshold=np.inf)

pd.set_option('display.width', 300) # 设置字符显示宽度
pd.set_option('display.max_rows', None) # 设置显示最大行
pd.set_option('display.max_columns', None) # 设置显示最大列，None为显示所有列


long_series = pd.Series(np.random.randn(1000))


y1_yticks_max = 12
y2_yticks_max = 12
fig_name ='../generate/Sagitta_SOTA.svg'
work = [    
            '[48]', 
            'SNAP',
            'TwoNullHop',
            'STICKER',
            'This Work\n(C3D)',
            'This Work\n(3D U-Net)']
energy_efficiency               = np.array([0.41, 0.91, 1.77, 3.48, 3.8, 4.5])
energy_efficiency_Improvement   = energy_efficiency / energy_efficiency[0]

x_value = np.arange(len(work))
# x_label = "${Works}$"

xticks = work
legend_loc = (0.01, 0.75)
len_yticks = [6, 11]
figsize=(7,3)

bar_width = 0.2
y1_yticks_max = 700
y2_yticks_max = 110

y_value = np.array([[energy_efficiency_Improvement]])
y_label = ['Normalized Energy Efficiency']
y_fig_type = [['bar', 'bar', 'bar'], ['bar']]
# y_legend = [['Normalized Energy Efficiency', 'Energy Consumption Reduction', 'Overall Efficiency Improvement']]
legend_ncol = 1
y_color=[[(49/255, 101/255, 162/255), (1, 1, 1), (220/255, 103/255, 103/255) ]]
y_yticks_max = [12]

# print(y_value)
# for j in range(3):
#     for i in range(len(work)):
#         print(y_value[0][j][-1]/y_value[0][j][i])

cls_plt_fig('').func_plt_fig(
    fig_name=fig_name,
    x_value=x_value,
    y_label = y_label,
    y_value = y_value,
    y_fig_type = y_fig_type,
    # y_legend = y_legend,
    y_color = y_color,
    y_axis_color = [(0, 0, 0)],
    y_edgecolor = [[(49/255, 101/255, 162/255), (49/255, 101/255, 162/255), (220/255, 103/255, 103/255)],[]],
    y_yticks_max=y_yticks_max,
    y_yticks_min=[0, 0],
    len_yticks=len_yticks,
    xticks= xticks,
    legend_loc =legend_loc,
    figsize=figsize, #[0, 0, 1, 1],
    font_size = 10,
    plt_text = True,
    # plt_text_first = True,
    legend_ncol=legend_ncol,
    labelrotation = 0,
    bar_width = bar_width,
    bar_gap_width = 0.08,
    border_width = 0.5
)
